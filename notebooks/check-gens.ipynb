# %%
import pandas as pd


df = pd.read_csv('/cronus_data/alahnala/empathy-generation/data/empo/preds_dlr1e6_zephyr-7b-sft-full122_d211.txt', sep='~')
df
# Out:
#       Unnamed: 0                                     chat_templates  \
# 0              0  <|system|>\nYou are a friendly assistant, who ...
# 1              1  <|system|>\nYou are a friendly assistant, who ...
# 2              2  <|system|>\nYou are a friendly assistant, who ...
# 3              3  <|system|>\nYou are a friendly assistant, who ...
# 4              4  <|system|>\nYou are a friendly assistant, who ...
# ...          ...                                                ...
# 2535        2535  <|system|>\nYou are a friendly assistant, who ...
# 2536        2536  <|system|>\nYou are a friendly assistant, who ...
# 2537        2537  <|system|>\nYou are a friendly assistant, who ...
# 2538        2538  <|system|>\nYou are a friendly assistant, who ...
# 2539        2539  <|system|>\nYou are a friendly assistant, who ...
#
#                                             gen_targets  \
# 0     Why did you feel guilty? People really shouldn...
# ...

# %%
df.iloc[951]
# Out:
# Unnamed: 0                                                      951
# chat_templates    <|system|>\nYou are a friendly assistant, who ...
# gen_targets       Woah plot twist. She brought him along to meet...
# prevs             Well, right after she gave me a big hug, she i...
# emotions                                                    jealous
# gens              OHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH...
# Name: 951, dtype: object

# %%
for gen in df.gens:
    print(gen)
# Out:
# Thankfully you were okay then. Drunk drivers are the worst.
# That is very sweet of him to always get you little gifts like that
# Exactly, I didn't want to leave my family but it was worth it. Now my property taxes are so low I can afford to do things with the extra money.
# No I do not. Been single for awhile now. What about your girlfriend is perfect?
# That is great. Sometimes they can make it hard on you.
# Yeah learn not to lend money to people who dont pay you back.
# Oh no! Why did you do that?
# Just close your eyes and hold on tight!   You will love it!
# He got sick really fast and we had to put him down :(
# Money does help with a lot of stress in life, but you can always make more if you work hard enough.
# I wish my neighborhood was like that.
# i watch everything really. from gaming to cooking shows to news to music videos. love youtube for everything!
# Yes you had to give in to that cake!
# Scared of what exactly? Cooking the steak?
# ...

# %%
df = pd.read_csv('/cronus_data/alahnala/empathy-generation/data/empo/preds_dlr1e6_zephyr-7b-sft-full122_d231.txt', sep='~')
df
# Out:
#       Unnamed: 0                                     chat_templates  \
# 0              0  <|system|>\nYou are a friendly assistant, who ...
# 1              1  <|system|>\nYou are a friendly assistant, who ...
# 2              2  <|system|>\nYou are a friendly assistant, who ...
# 3              3  <|system|>\nYou are a friendly assistant, who ...
# 4              4  <|system|>\nYou are a friendly assistant, who ...
# ...          ...                                                ...
# 2535        2535  <|system|>\nYou are a friendly assistant, who ...
# 2536        2536  <|system|>\nYou are a friendly assistant, who ...
# 2537        2537  <|system|>\nYou are a friendly assistant, who ...
# 2538        2538  <|system|>\nYou are a friendly assistant, who ...
# 2539        2539  <|system|>\nYou are a friendly assistant, who ...
#
#                                             gen_targets  \
# 0     Why did you feel guilty? People really shouldn...
# ...
