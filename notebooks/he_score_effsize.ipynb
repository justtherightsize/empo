# %%
import json
import pandas as pd
import numpy as np

ann_df = pd.read_csv("human_evaluation/he_data.csv", index_col=0)

dims = ['Dim1', 'Dim2', 'Dim3', 'Dim4', 'Dim5']

ann_df.head(3)
# Out:
#    sample_index  Dim1  Dim2  Dim3  Dim4  Dim5  annotator  ED_index  \
# 0             0    70    82    49    44     1          1       343
# 1             1    70    57    70    70     1          1       274
# 2             2    62    11    24    14     1          1      2061
#
#                                       chat_templates  \
# 0  <|system|>\nYou are a friendly assistant, who ...
# 1  <|system|>\nYou are a friendly assistant, who ...
# 2  <|system|>\nYou are a friendly assistant, who ...
#
#                                          gen_targets  \
# 0            so young and ready to conquer the world
# 1  Wow, that is terrible. I hope that you are abl...
# 2  It's good that you're being more proactive abo...
#
#                                                prevs   emotions  \
# 0  It is!  In it, she's just standing with a huge...  nostalgic
# 1  Huge dent, I can't believe someone could do th...    furious
# 2  I'll try to do my best. i think i will also ne...      proud
#
#                                                 gens  \
# 0  I can imagine how happy she must have been on ...
# 1  That's really unfortunate. I'm sorry to hear t...
# 2  It's always a good idea to consult with a doct...
#
#                                             chat_cut  \
# 0  I found an old picture of when my oldest daugh...
# 1  Someone hit my car while I was shopping. I am ...
# 2  I stress eat a lot. I decided i need to contro...
#
#                                            tidy_chat        model
# 0  Speaker: I found an old picture of when my old...  zephyr_base
# 1  Speaker: Someone hit my car while I was shoppi...  zephyr_base
# 2  Speaker: I stress eat a lot. I decided i need ...  zephyr_base

# %%
ann_mean_df = ann_df.groupby(["model", "ED_index"])[dims].mean().reset_index()
sample_data_df = ann_df[["emotions", "model", "tidy_chat", "ED_index", "gens"]].drop_duplicates()
res_df = ann_mean_df.merge(sample_data_df, on=["ED_index", "model"])
res_df.drop(columns='ED_index').groupby("model").describe().round(2).T
# Out:
# model          SFT  human_targets  zephyr_base  zephyr_base_output_limit  \
# Dim1 count  135.00         135.00       135.00                    135.00
#      mean    73.33          71.89        80.38                     74.31
#      std     15.68          16.24        12.56                     18.31
#      min     23.67          14.33        27.67                      5.67
#      25%     64.33          64.33        73.83                     64.67
#      50%     77.33          75.00        82.67                     78.67
#      75%     83.67          82.50        89.00                     86.83
#      max    100.00          98.33       100.00                    100.00
# Dim2 count  135.00         135.00       135.00                    135.00
#      mean    63.06          60.27        75.96                     68.23
#      std     19.51          19.20        16.33                     20.09
#      min     14.67          10.67        11.00                      7.00
#      25%     49.33          48.50        68.83                     56.33
#      50%     63.67          62.67        79.67                     71.33
#      75%     79.17          75.00        87.00                     84.17
#      max    100.00          95.00       100.00                     98.00
# Dim3 count  135.00         135.00       135.00                    135.00
#      mean    68.83          67.73        75.41                     70.32
#      std     15.83          17.10        15.17                     18.83
#      min     22.33          12.33        28.33                      0.00
#      25%     60.83          58.17        66.00                     61.33
#      50%     72.33          69.33        77.33                     73.00
#      75%     80.00          80.17        87.17                     83.33
#      max     97.00         100.00       100.00                     98.33
# Dim4 count  135.00         135.00       135.00                    135.00
#      mean    62.65          63.42        71.92                     63.42
#      std     18.57          19.49        16.49                     21.33
#      min      9.33           2.33        23.00                      0.00
#      25%     53.33          51.00        63.33                     51.33
#      50%     64.33          65.00        73.33                     65.67
#      75%     77.33          79.50        85.00                     80.33
#      max     94.33         100.00       100.00                    100.00
# Dim5 count  135.00         135.00       135.00                    135.00
#      mean     0.91           0.93         0.93                      0.92
#      std      0.19           0.15         0.15                      0.16
#      min      0.00           0.33         0.33                      0.33
#      25%      1.00           1.00         1.00                      1.00
#      50%      1.00           1.00         1.00                      1.00
#      75%      1.00           1.00         1.00                      1.00
#      max      1.00           1.00         1.00                      1.00
#
# model       zephyr_dpo
# Dim1 count      135.00
#      mean        74.91
#      std         16.02
#      min         35.00
#      25%         64.33
#      50%         76.33
#      75%         87.33
#      max        100.00
# Dim2 count      135.00
#      mean        63.11
#      std         20.47
#      min         10.33
#      25%         48.17
#      50%         66.00
#      75%         79.33
#      max        100.00
# Dim3 count      135.00
#      mean        72.86
#      std         15.41
#      min         31.67
#      25%         61.50
#      50%         74.33
#      75%         84.17
#      max        100.00
# Dim4 count      135.00
#      mean        66.75
#      std         18.09
#      min         18.33
#      25%         55.33
#      50%         66.33
#      75%         80.00
#      max        100.00
# Dim5 count      135.00
#      mean         0.93
#      std          0.15
#      min          0.33
#      25%          1.00
#      50%          1.00
#      75%          1.00
#      max          1.00

# %% [markdown]
# ### Effect sizes of the score differences

# %% [markdown]
# The sample sizes are large enough to assume normality from the central limit theorem

# %%
def cohend(d1, d2):
    s = np.sqrt(((len(d1) - 1) * np.var(d1, ddof=1) + (len(d2) - 1) * np.var(d2, ddof=1)) / (len(d1) + len(d2) - 2))
    return (np.mean(d1) - np.mean(d2)) / s

# %%
from scipy.stats import ttest_rel, f_oneway


models = ['zephyr_base', 'zephyr_dpo', 'zephyr_base_output_limit', 'SFT', 'human_targets']
t_test_sig_res = []

for model_orig in models:
    for dim in dims[:-1]:
        for i, model in enumerate(models):
            ann_A = res_df[res_df.model == model][dim]
            ann_B = res_df[res_df.model == model_orig][dim]
            p_res =  ttest_rel(ann_A, ann_B, alternative='greater').pvalue
            effsize_d = cohend(ann_A, ann_B)
            # print(f'Comparing {model_orig} to {model}, {dim}, t={t_res}, Effect_size: {effsize_d}')
            t_test_sig_res.append([dim, model, model_orig, p_res, effsize_d])

effsize_df = pd.DataFrame(t_test_sig_res, columns=['dim', 'model_greater_score', 'model', 'p', 'effect_size']).dropna()
effsize_df[effsize_df.p < 0.05].sort_values(["dim", "effect_size"], ascending=False).round({'p':5, 'effect_size': 2})
# Out:
#      dim       model_greater_score                     model        p  \
# 75  Dim4               zephyr_base                       SFT  0.00001
# 95  Dim4               zephyr_base             human_targets  0.00004
# 55  Dim4               zephyr_base  zephyr_base_output_limit  0.00005
# 35  Dim4               zephyr_base                zephyr_dpo  0.00962
# 76  Dim4                zephyr_dpo                       SFT  0.02322
# 90  Dim3               zephyr_base             human_targets  0.00003
# 70  Dim3               zephyr_base                       SFT  0.00013
# 91  Dim3                zephyr_dpo             human_targets  0.00491
# 50  Dim3               zephyr_base  zephyr_base_output_limit  0.00372
# 71  Dim3                zephyr_dpo                       SFT  0.01041
# 85  Dim2               zephyr_base             human_targets  0.00000
# 65  Dim2               zephyr_base                       SFT  0.00000
# 25  Dim2               zephyr_base                zephyr_dpo  0.00000
# 45  Dim2               zephyr_base  zephyr_base_output_limit  0.00013
# 87  Dim2  zephyr_base_output_limit             human_targets  0.00013
# 67  Dim2  zephyr_base_output_limit                       SFT  0.00674
# 27  Dim2  zephyr_base_output_limit                zephyr_dpo  0.01469
# 80  Dim1               zephyr_base             human_targets  0.00000
# 60  Dim1               zephyr_base                       SFT  0.00002
# 40  Dim1               zephyr_base  zephyr_base_output_limit  0.00007
# 20  Dim1               zephyr_base                zephyr_dpo  0.00075
#
#     effect_size
# 75         0.53
# 95         0.47
# 55         0.45
# 35         0.30
# 76         0.22
# 90         0.48
# 70         0.42
# 91         0.32
# 50         0.30
# 71         0.26
# 85         0.88
# 65         0.72
# 25         0.69
# 45         0.42
# 87         0.40
# 67         0.26
# 27         0.25
# 80         0.58
# 60         0.50
# 40         0.39
# 20         0.38

# %% [markdown]
# ### Relation of length, emotion and the final score

# %%
from scipy.stats import pearsonr
from functools import reduce


res_x = res_df.copy()
res_x['len'] = res_x.gens.str.len()

# %%
continuous_dim_count = 4
res_dim = [[] for _ in range(continuous_dim_count)]

for i in range(1, continuous_dim_count + 1):
    for em in res_x.emotions.unique():
        res_em = res_x[res_x.emotions == em]
        pear_res = pearsonr(res_em['len'], res_em[f'Dim{i}'])
        res_dim[i - 1] += [[pear_res.statistic, pear_res.pvalue, em]]

# %%
gen_len_df = res_x.groupby(['emotions', 'model'])['len'].mean().unstack('model').add_prefix('gen_length_')
em_corr_arr = [gen_len_df]

for i in range(1, continuous_dim_count + 1):
    em_corr = pd.DataFrame(res_dim[i - 1], columns=[f'correlation_dim{i}', f'p_dim{i}', 'emotions'])
    gen_dim = res_x.groupby(['emotions', 'model'])[f'Dim{i}'].mean().unstack('model').add_prefix(f'dim{i}_score_')
    em_corr_arr = [em_corr] + em_corr_arr + [gen_dim] 

em_corr_df = reduce(lambda l, r: pd.merge(l, r, on=["emotions"]), em_corr_arr).round(2)
em_corr_df = em_corr_df.sort_values(by="gen_length_zephyr_base",ascending=False)
#em_corr_df.reindex(sorted(em_corr_df.columns), axis=1)

# %%
em_corr_df
# Out:
#     correlation_dim4  p_dim4      emotions  correlation_dim3  p_dim3  \
# 0               0.02    0.93        guilty             -0.16    0.51
# 4              -0.18    0.44  apprehensive             -0.36    0.12
# 17              0.13    0.59     impressed             -0.35    0.14
# 24              0.04    0.87        lonely             -0.06    0.80
# 20              0.06    0.79           sad              0.36    0.08
# 21              0.40    0.08         angry              0.53    0.02
# 18              0.30    0.20    devastated              0.28    0.23
# 10              0.55    0.01     confident              0.03    0.90
# 5              -0.01    0.98        caring             -0.10    0.69
# 23              0.29    0.22        joyful             -0.03    0.90
# 9               0.27    0.26       jealous              0.17    0.48
# 7              -0.03    0.91   embarrassed             -0.44    0.05
# 8              -0.13    0.58  anticipating              0.14    0.56
# 27              0.44    0.05      faithful              0.07    0.76
# 14             -0.12    0.62  disappointed             -0.01    0.96
# 30             -0.06    0.82       annoyed              0.06    0.80
# 16             -0.06    0.79       anxious             -0.09    0.71
# 22              0.09    0.60         proud             -0.05    0.77
# 12              0.09    0.72     nostalgic             -0.11    0.66
# 2               0.27    0.25      trusting              0.29    0.21
# 6              -0.13    0.58       content             -0.08    0.74
# 26              0.38    0.10       furious             -0.04    0.88
# 11              0.05    0.84      prepared              0.04    0.87
# 31              0.08    0.74       excited              0.00    0.99
# 3               0.34    0.15       ashamed              0.05    0.84
# 29              0.08    0.75      grateful              0.16    0.51
# 28              0.30    0.20   sentimental              0.17    0.47
# 19              0.30    0.19     terrified              0.30    0.20
# 15              0.24    0.32     disgusted             -0.21    0.38
# 25              0.25    0.30        afraid              0.32    0.17
# 13              0.32    0.17       hopeful              0.21    0.38
# 1               0.34    0.04     surprised              0.23    0.18
#
#     correlation_dim2  p_dim2  correlation_dim1  p_dim1  gen_length_SFT  ...  \
# 0               0.14    0.56             -0.01    0.96           38.00  ...
# 4               0.20    0.41             -0.21    0.36          155.25  ...
# 17              0.11    0.64             -0.07    0.77           50.75  ...
# 24              0.05    0.83             -0.11    0.65           40.00  ...
# 20              0.41    0.04              0.45    0.02           67.80  ...
# 21              0.56    0.01              0.39    0.09           40.75  ...
# 18              0.23    0.32              0.18    0.44           68.50  ...
# 10              0.34    0.14              0.43    0.06           39.75  ...
# 5               0.11    0.65             -0.14    0.55           47.25  ...
# 23              0.25    0.29              0.16    0.51           43.00  ...
# 9               0.39    0.09              0.30    0.20           55.75  ...
# 7              -0.23    0.33             -0.16    0.51           45.75  ...
# 8               0.19    0.42              0.01    0.96           47.25  ...
# 27              0.39    0.09              0.24    0.31           55.50  ...
# 14              0.32    0.17              0.10    0.66           44.75  ...
# 30              0.32    0.17              0.22    0.35           42.75  ...
# 16              0.24    0.31             -0.10    0.68           51.25  ...
# 22             -0.13    0.45              0.02    0.90           43.57  ...
# 12              0.37    0.11              0.24    0.30           38.00  ...
# 2               0.55    0.01              0.31    0.18           39.50  ...
# 6              -0.21    0.37             -0.19    0.43           50.00  ...
# 26              0.05    0.84              0.08    0.72           51.25  ...
# 11              0.37    0.11              0.23    0.33           43.50  ...
# 31              0.06    0.80             -0.06    0.79           37.50  ...
# 3               0.37    0.11              0.07    0.78           27.00  ...
# 29              0.27    0.24              0.07    0.76           43.75  ...
# 28              0.32    0.18              0.10    0.67           54.25  ...
# 19              0.73    0.00              0.45    0.05           38.25  ...
# 15              0.29    0.22             -0.07    0.75           36.50  ...
# 25              0.43    0.06              0.37    0.11           53.75  ...
# 13              0.36    0.12              0.40    0.08           43.50  ...
# 1               0.24    0.17              0.25    0.16           34.86  ...
#
#     dim3_score_SFT  dim3_score_human_targets  dim3_score_zephyr_base  \
# 0            76.58                     59.58                   67.58
# 4            60.83                     72.58                   72.25
# 17           80.00                     70.08                   68.83
# 24           59.67                     68.33                   66.67
# 20           76.53                     70.27                   84.73
# 21           64.42                     65.92                   82.25
# 18           71.50                     64.00                   81.42
# 10           65.67                     72.58                   78.83
# 5            66.08                     65.75                   75.92
# 23           82.83                     59.08                   74.58
# 9            60.83                     64.33                   67.33
# 7            72.33                     70.33                   65.92
# 8            58.33                     73.33                   76.67
# 27           77.17                     66.00                   79.83
# 14           62.83                     70.75                   70.58
# 30           73.75                     74.83                   76.17
# 16           74.83                     64.42                   74.58
# 22           60.86                     71.67                   70.38
# 12           68.75                     76.08                   75.25
# 2            60.33                     51.08                   69.67
# 6            81.08                     53.50                   79.00
# 26           70.00                     78.75                   78.00
# 11           70.50                     82.42                   82.58
# 31           82.33                     68.33                   72.67
# 3            60.83                     70.00                   77.92
# 29           77.17                     54.17                   88.08
# 28           66.92                     69.08                   62.83
# 19           58.33                     52.17                   81.92
# 15           69.58                     76.58                   67.00
# 25           68.33                     60.42                   79.33
# 13           67.92                     78.33                   82.08
# 1            63.57                     68.38                   80.19
#
#     dim3_score_zephyr_base_output_limit  dim3_score_zephyr_dpo  \
# 0                                 64.58                  78.67
# 4                                 62.67                  74.58
# 17                                72.42                  68.33
# 24                                71.17                  79.58
# 20                                62.87                  69.60
# 21                                80.17                  60.58
# 18                                71.42                  71.42
# 10                                69.25                  65.50
# 5                                 75.08                  56.08
# 23                                86.58                  68.50
# 9                                 77.25                  59.33
# 7                                 74.67                  77.75
# 8                                 60.75                  73.67
# 27                                80.92                  65.17
# 14                                70.92                  65.67
# 30                                78.75                  74.42
# 16                                49.67                  74.08
# 22                                69.62                  73.86
# 12                                60.25                  84.67
# 2                                 70.17                  86.67
# 6                                 74.50                  86.42
# 26                                80.33                  77.58
# 11                                67.17                  79.50
# 31                                86.08                  72.67
# 3                                 46.75                  79.83
# 29                                74.67                  75.58
# 28                                43.58                  74.83
# 19                                67.50                  64.33
# 15                                75.75                  75.33
# 25                                67.42                  79.42
# 13                                80.42                  63.75
# 1                                 75.52                  73.67
#
#     dim4_score_SFT  dim4_score_human_targets  dim4_score_zephyr_base  \
# 0            75.75                     55.25                   72.00
# 4            46.50                     63.33                   68.08
# 17           71.42                     59.00                   75.08
# 24           49.92                     61.83                   60.08
# 20           74.33                     67.33                   68.40
# 21           64.08                     70.33                   70.25
# 18           67.58                     35.33                   76.33
# 10           56.17                     81.58                   86.75
# 5            57.17                     59.58                   74.75
# 23           78.83                     54.75                   79.17
# 9            54.08                     47.00                   59.00
# 7            58.50                     65.08                   67.17
# 8            62.67                     71.25                   62.92
# 27           68.50                     68.00                   90.17
# 14           59.33                     60.58                   58.42
# 30           61.42                     71.92                   71.17
# 16           71.75                     68.17                   72.08
# 22           60.67                     73.38                   69.76
# 12           62.00                     76.50                   75.00
# 2            55.08                     48.58                   67.67
# 6            83.33                     58.50                   75.08
# 26           61.67                     72.08                   78.67
# 11           70.50                     80.67                   71.58
# 31           83.75                     53.17                   69.75
# 3            36.08                     65.42                   78.50
# 29           73.50                     42.33                   79.58
# 28           59.17                     66.83                   66.83
# 19           57.50                     62.17                   80.33
# 15           55.83                     64.25                   66.25
# 25           57.08                     65.58                   65.75
# 13           62.00                     69.17                   74.25
# 1            53.86                     62.71                   72.62
#
#     dim4_score_zephyr_base_output_limit  dim4_score_zephyr_dpo
# 0                                 54.00                  77.33
# 4                                 50.92                  61.08
# 17                                59.58                  68.92
# 24                                66.50                  73.75
# 20                                51.93                  68.53
# 21                                72.17                  58.00
# 18                                61.33                  57.33
# 10                                75.75                  64.75
# 5                                 75.00                  47.00
# 23                                71.42                  56.00
# 9                                 68.67                  74.08
# 7                                 63.83                  78.75
# 8                                 60.75                  68.75
# 27                                88.92                  50.08
# 14                                63.33                  52.67
# 30                                63.08                  74.17
# 16                                52.92                  71.00
# 22                                67.86                  66.71
# 12                                57.75                  82.92
# 2                                 58.75                  64.42
# 6                                 56.50                  65.25
# 26                                73.33                  58.67
# 11                                54.83                  76.25
# 31                                71.58                  60.42
# 3                                 40.00                  72.17
# 29                                62.75                  84.00
# 28                                48.17                  62.42
# 19                                55.83                  56.42
# 15                                64.50                  67.25
# 25                                61.33                  71.00
# 13                                82.42                  68.00
# 1                                 69.10                  72.86
#
# [32 rows x 34 columns]

# %%
em_corr_df.sort_values(by="correlation_dim1",ascending=False)
# Out:
#     correlation_dim4  p_dim4      emotions  correlation_dim3  p_dim3  \
# 20              0.06    0.79           sad              0.36    0.08
# 19              0.30    0.19     terrified              0.30    0.20
# 10              0.55    0.01     confident              0.03    0.90
# 13              0.32    0.17       hopeful              0.21    0.38
# 21              0.40    0.08         angry              0.53    0.02
# 25              0.25    0.30        afraid              0.32    0.17
# 2               0.27    0.25      trusting              0.29    0.21
# 9               0.27    0.26       jealous              0.17    0.48
# 1               0.34    0.04     surprised              0.23    0.18
# 27              0.44    0.05      faithful              0.07    0.76
# 12              0.09    0.72     nostalgic             -0.11    0.66
# 11              0.05    0.84      prepared              0.04    0.87
# 30             -0.06    0.82       annoyed              0.06    0.80
# 18              0.30    0.20    devastated              0.28    0.23
# 23              0.29    0.22        joyful             -0.03    0.90
# 28              0.30    0.20   sentimental              0.17    0.47
# 14             -0.12    0.62  disappointed             -0.01    0.96
# 26              0.38    0.10       furious             -0.04    0.88
# 29              0.08    0.75      grateful              0.16    0.51
# 3               0.34    0.15       ashamed              0.05    0.84
# 22              0.09    0.60         proud             -0.05    0.77
# 8              -0.13    0.58  anticipating              0.14    0.56
# 0               0.02    0.93        guilty             -0.16    0.51
# 31              0.08    0.74       excited              0.00    0.99
# 15              0.24    0.32     disgusted             -0.21    0.38
# 17              0.13    0.59     impressed             -0.35    0.14
# 16             -0.06    0.79       anxious             -0.09    0.71
# 24              0.04    0.87        lonely             -0.06    0.80
# 5              -0.01    0.98        caring             -0.10    0.69
# 7              -0.03    0.91   embarrassed             -0.44    0.05
# 6              -0.13    0.58       content             -0.08    0.74
# 4              -0.18    0.44  apprehensive             -0.36    0.12
#
#     correlation_dim2  p_dim2  correlation_dim1  p_dim1  gen_length_SFT  ...  \
# 20              0.41    0.04              0.45    0.02           67.80  ...
# 19              0.73    0.00              0.45    0.05           38.25  ...
# 10              0.34    0.14              0.43    0.06           39.75  ...
# 13              0.36    0.12              0.40    0.08           43.50  ...
# 21              0.56    0.01              0.39    0.09           40.75  ...
# 25              0.43    0.06              0.37    0.11           53.75  ...
# 2               0.55    0.01              0.31    0.18           39.50  ...
# 9               0.39    0.09              0.30    0.20           55.75  ...
# 1               0.24    0.17              0.25    0.16           34.86  ...
# 27              0.39    0.09              0.24    0.31           55.50  ...
# 12              0.37    0.11              0.24    0.30           38.00  ...
# 11              0.37    0.11              0.23    0.33           43.50  ...
# 30              0.32    0.17              0.22    0.35           42.75  ...
# 18              0.23    0.32              0.18    0.44           68.50  ...
# 23              0.25    0.29              0.16    0.51           43.00  ...
# 28              0.32    0.18              0.10    0.67           54.25  ...
# 14              0.32    0.17              0.10    0.66           44.75  ...
# 26              0.05    0.84              0.08    0.72           51.25  ...
# 29              0.27    0.24              0.07    0.76           43.75  ...
# 3               0.37    0.11              0.07    0.78           27.00  ...
# 22             -0.13    0.45              0.02    0.90           43.57  ...
# 8               0.19    0.42              0.01    0.96           47.25  ...
# 0               0.14    0.56             -0.01    0.96           38.00  ...
# 31              0.06    0.80             -0.06    0.79           37.50  ...
# 15              0.29    0.22             -0.07    0.75           36.50  ...
# 17              0.11    0.64             -0.07    0.77           50.75  ...
# 16              0.24    0.31             -0.10    0.68           51.25  ...
# 24              0.05    0.83             -0.11    0.65           40.00  ...
# 5               0.11    0.65             -0.14    0.55           47.25  ...
# 7              -0.23    0.33             -0.16    0.51           45.75  ...
# 6              -0.21    0.37             -0.19    0.43           50.00  ...
# 4               0.20    0.41             -0.21    0.36          155.25  ...
#
#     dim3_score_SFT  dim3_score_human_targets  dim3_score_zephyr_base  \
# 20           76.53                     70.27                   84.73
# 19           58.33                     52.17                   81.92
# 10           65.67                     72.58                   78.83
# 13           67.92                     78.33                   82.08
# 21           64.42                     65.92                   82.25
# 25           68.33                     60.42                   79.33
# 2            60.33                     51.08                   69.67
# 9            60.83                     64.33                   67.33
# 1            63.57                     68.38                   80.19
# 27           77.17                     66.00                   79.83
# 12           68.75                     76.08                   75.25
# 11           70.50                     82.42                   82.58
# 30           73.75                     74.83                   76.17
# 18           71.50                     64.00                   81.42
# 23           82.83                     59.08                   74.58
# 28           66.92                     69.08                   62.83
# 14           62.83                     70.75                   70.58
# 26           70.00                     78.75                   78.00
# 29           77.17                     54.17                   88.08
# 3            60.83                     70.00                   77.92
# 22           60.86                     71.67                   70.38
# 8            58.33                     73.33                   76.67
# 0            76.58                     59.58                   67.58
# 31           82.33                     68.33                   72.67
# 15           69.58                     76.58                   67.00
# 17           80.00                     70.08                   68.83
# 16           74.83                     64.42                   74.58
# 24           59.67                     68.33                   66.67
# 5            66.08                     65.75                   75.92
# 7            72.33                     70.33                   65.92
# 6            81.08                     53.50                   79.00
# 4            60.83                     72.58                   72.25
#
#     dim3_score_zephyr_base_output_limit  dim3_score_zephyr_dpo  \
# 20                                62.87                  69.60
# 19                                67.50                  64.33
# 10                                69.25                  65.50
# 13                                80.42                  63.75
# 21                                80.17                  60.58
# 25                                67.42                  79.42
# 2                                 70.17                  86.67
# 9                                 77.25                  59.33
# 1                                 75.52                  73.67
# 27                                80.92                  65.17
# 12                                60.25                  84.67
# 11                                67.17                  79.50
# 30                                78.75                  74.42
# 18                                71.42                  71.42
# 23                                86.58                  68.50
# 28                                43.58                  74.83
# 14                                70.92                  65.67
# 26                                80.33                  77.58
# 29                                74.67                  75.58
# 3                                 46.75                  79.83
# 22                                69.62                  73.86
# 8                                 60.75                  73.67
# 0                                 64.58                  78.67
# 31                                86.08                  72.67
# 15                                75.75                  75.33
# 17                                72.42                  68.33
# 16                                49.67                  74.08
# 24                                71.17                  79.58
# 5                                 75.08                  56.08
# 7                                 74.67                  77.75
# 6                                 74.50                  86.42
# 4                                 62.67                  74.58
#
#     dim4_score_SFT  dim4_score_human_targets  dim4_score_zephyr_base  \
# 20           74.33                     67.33                   68.40
# 19           57.50                     62.17                   80.33
# 10           56.17                     81.58                   86.75
# 13           62.00                     69.17                   74.25
# 21           64.08                     70.33                   70.25
# 25           57.08                     65.58                   65.75
# 2            55.08                     48.58                   67.67
# 9            54.08                     47.00                   59.00
# 1            53.86                     62.71                   72.62
# 27           68.50                     68.00                   90.17
# 12           62.00                     76.50                   75.00
# 11           70.50                     80.67                   71.58
# 30           61.42                     71.92                   71.17
# 18           67.58                     35.33                   76.33
# 23           78.83                     54.75                   79.17
# 28           59.17                     66.83                   66.83
# 14           59.33                     60.58                   58.42
# 26           61.67                     72.08                   78.67
# 29           73.50                     42.33                   79.58
# 3            36.08                     65.42                   78.50
# 22           60.67                     73.38                   69.76
# 8            62.67                     71.25                   62.92
# 0            75.75                     55.25                   72.00
# 31           83.75                     53.17                   69.75
# 15           55.83                     64.25                   66.25
# 17           71.42                     59.00                   75.08
# 16           71.75                     68.17                   72.08
# 24           49.92                     61.83                   60.08
# 5            57.17                     59.58                   74.75
# 7            58.50                     65.08                   67.17
# 6            83.33                     58.50                   75.08
# 4            46.50                     63.33                   68.08
#
#     dim4_score_zephyr_base_output_limit  dim4_score_zephyr_dpo
# 20                                51.93                  68.53
# 19                                55.83                  56.42
# 10                                75.75                  64.75
# 13                                82.42                  68.00
# 21                                72.17                  58.00
# 25                                61.33                  71.00
# 2                                 58.75                  64.42
# 9                                 68.67                  74.08
# 1                                 69.10                  72.86
# 27                                88.92                  50.08
# 12                                57.75                  82.92
# 11                                54.83                  76.25
# 30                                63.08                  74.17
# 18                                61.33                  57.33
# 23                                71.42                  56.00
# 28                                48.17                  62.42
# 14                                63.33                  52.67
# 26                                73.33                  58.67
# 29                                62.75                  84.00
# 3                                 40.00                  72.17
# 22                                67.86                  66.71
# 8                                 60.75                  68.75
# 0                                 54.00                  77.33
# 31                                71.58                  60.42
# 15                                64.50                  67.25
# 17                                59.58                  68.92
# 16                                52.92                  71.00
# 24                                66.50                  73.75
# 5                                 75.00                  47.00
# 7                                 63.83                  78.75
# 6                                 56.50                  65.25
# 4                                 50.92                  61.08
#
# [32 rows x 34 columns]

# %%
d = 1
alpha = 0.5
model = "zephyr_base"
em_corr_df[[f"correlation_dim{d}", f"p_dim{d}", "emotions", f"dim{d}_score_{model}"]][em_corr_df[f"p_dim{d}"] < alpha].sort_values(by=f"correlation_dim{d}", ascending=False)
# Out:
#     correlation_dim1  p_dim1      emotions  dim1_score_zephyr_base
# 20              0.45    0.02           sad                   87.53
# 19              0.45    0.05     terrified                   83.42
# 10              0.43    0.06     confident                   89.67
# 13              0.40    0.08       hopeful                   88.50
# 21              0.39    0.09         angry                   82.50
# 25              0.37    0.11        afraid                   81.33
# 2               0.31    0.18      trusting                   80.17
# 9               0.30    0.20       jealous                   73.17
# 1               0.25    0.16     surprised                   81.43
# 27              0.24    0.31      faithful                   88.33
# 12              0.24    0.30     nostalgic                   87.50
# 11              0.23    0.33      prepared                   82.83
# 30              0.22    0.35       annoyed                   80.33
# 18              0.18    0.44    devastated                   83.25
# 6              -0.19    0.43       content                   82.58
# 4              -0.21    0.36  apprehensive                   85.58
